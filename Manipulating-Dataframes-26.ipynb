# %% [markdown]
# # Manipulating Dataframes

# %% [markdown]
# In the previous tutorial we covered what a dataframe is, and how to create and access it. Now we will look at how to manipulate dataframes and when to use a dataframe as the chosen data structure.
#
# Let's start by importing the pandas library and the football_players.csv we used in the previous tutorial.

# %%
import pandas as pd

# %%
# Load data - pass 'Name' as our index column
load_df = pd.read_csv('C:/Users/alfred/Downloads/pandas/football_players-a-26.csv', index_col='Name')

# Create dataframe called df
df = pd.DataFrame(load_df)

# Use the head() function to look at the first 5 rows
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing   Curve Dribbling  \
# Name
# Cristiano Ronaldo  63           93        95       85      81        91
# L. Messi           95           95        96       77      89        97
# Neymar             82           95        92       75      81        96
# L. Suárez          60           91        83       77      86        86
# M. Neuer           35           48        70       15      14        30
#
#                   Finishing Free kick accuracy GK diving GK handling  \
# Name
# Cristiano Ronaldo    94                 76         7          11
# L. Messi             95                 90         6          11
# Neymar               89                 84         9           9
# L. Suárez            94                 84        27          25
# M. Neuer             13                 11        91          90
#
#                   GK kicking GK positioning GK reflexes Heading accuracy  \
# Name
# Cristiano Ronaldo     15             14          11               88
# L. Messi              15             14           8               71
# Neymar                15             15          11               62
# L. Suárez             31             33          37               77
# M. Neuer              95             91          89               25
#
#                   Interceptions Jumping Long passing Long shots Marking  \
# Name
# Cristiano Ronaldo        29      95           77         92      22
# L. Messi                 22      68           87         88      13
# Neymar                   36      61           75         77      21
# L. Suárez                41      69           64         86      30
# M. Neuer                 30      78           59         16      10
#
#                   Penalties Positioning Reactions Short passing Shot power  \
# Name
# Cristiano Ronaldo    85          95        96            83         94
# L. Messi             74          93        95            88         85
# Neymar               81          90        88            81         80
# L. Suárez            85          92        93            83         87
# M. Neuer             47          12        85            55         25
#
#                   Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# Cristiano Ronaldo         23           91      92              31
# L. Messi                  26           87      73              28
# Neymar                    33           90      78              24
# L. Suárez                 38           77      89              45
# M. Neuer                  11           61      44              10
#
#                   Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo   80      85      88                  ST LW
# L. Messi            59      90      85                     RW
# Neymar              53      80      83                     LW
# L. Suárez           80      84      88                     ST
# M. Neuer            83      70      11                     GK

# %% [markdown]
# ## Sorting

# %% [markdown]
# Usually one of the first things that is done when working with a large dataset is to sort the values using some criteria. This can be done by using the `sort_values()` function. We need to pass the column to sort by. Let's look at some examples:

# %%
# Sort by age from youngest to oldest (select first 5 entries)
df.sort_values(by='Age').head()
# Out:
#               Age  Nationality  Overall Acceleration Aggression Agility  \
# Name
# J. Romero      16    Argentina       58       75         36      70
# J. Hove        16       Norway       51       57         57      58
# Javi Vázquez   16        Spain       58       61         53      48
# K. Pierie      16  Netherlands       65       72         64      66
# L. Pintor      16       France       54       72         29      70
#
#              Balance Ball control Composure Crossing         ...          \
# Name                                                         ...
# J. Romero     86           55        59       46             ...
# J. Hove       56           51        42       40             ...
# Javi Vázquez  65           47        43       33             ...
# K. Pierie     53           65        66       47             ...
# L. Pintor     68           56        43       27             ...
#
#              Short passing Shot power Sliding tackle Sprint speed Stamina  \
# Name
# J. Romero           52         54             25           77      58
# J. Hove             56         50             56           64      47
# Javi Vázquez        41         42             59           64      59
# K. Pierie           68         35             62           72      45
# L. Pintor           30         57             12           68      36
#
#              Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# J. Romero             26       41      51      45                     ST
# J. Hove               51       54      56      29                     CM
# Javi Vázquez          63       55      37      29                     CB
# K. Pierie             67       65      56      32                  LB CB
# L. Pintor             10       34      38      48                     ST
#
# [5 rows x 38 columns]

# %% [markdown]
# When sorting values, the default is always ascending. If we want to sort in decending order, we need to pass ascending=False.

# %%
# Sort by age from oldest to youngest (select first 5 entries)
df.sort_values(by='Age', ascending=False).head()
# Out:
#                Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# B. Richardson   47     England       46       25         44      35
# E. El Hadary    44       Egypt       70       28         29      21
# O. Pérez        44      Mexico       71       60         26      69
# J. Walker       43     England       55       22         41      53
# D. Coyne        43       Wales       55       36         36      48
#
#               Balance Ball control Composure Crossing         ...          \
# Name                                                          ...
# B. Richardson  44           22        44       11             ...
# E. El Hadary   41           25        57       20             ...
# O. Pérez       69           23        50       19             ...
# J. Walker      64           38        35       16             ...
# D. Coyne       58           31        57       13             ...
#
#               Short passing Shot power Sliding tackle Sprint speed Stamina  \
# Name
# B. Richardson        12         13             13           25      32
# E. El Hadary         16         18             15           39      34
# O. Pérez             26         24             11           57      41
# J. Walker            22         22             13           35      19
# D. Coyne             28         21             19           33      37
#
#               Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# B. Richardson          12       47      17      12                     GK
# E. El Hadary           19       73      16      12                     GK
# O. Pérez               12       66      40      13                     GK
# J. Walker              11       62      32      11                     GK
# D. Coyne               16       76      33      11                     GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Filtering

# %% [markdown]
# A very useful thing to do with a dataframe is to filter the values to only view the data you are interested in. We can do this by passing a condition inside square brackets after the dataframe, eg. the syntax will look like dataframe[condition]. Let's look at a few examples:

# %%
# Filter on players older than 30
df[df['Age'] > 30]
# Out:
#                    Age          Nationality  Overall Acceleration Aggression  \
# Name
# Cristiano Ronaldo   32             Portugal       94       89         63
# M. Neuer            31              Germany       92       58         29
# Sergio Ramos        31                Spain       90       75         84
# L. Modrić           31              Croatia       89       75         62
# G. Chiellini        32                Italy       89       68         92
# G. Buffon           39                Italy       89       49         38
# D. Godín            31              Uruguay       88       62         86
# Thiago Silva        32               Brazil       88       70         77
# Z. Ibrahimović      35               Sweden       88       63         84
# A. Robben           33          Netherlands       88       87         47
# David Silva         31                Spain       87       72         51
# S. Handanovič       32             Slovenia       87       54         25
# Iniesta             33                Spain       87       72         58
# Miranda             32               Brazil       86       67         83
# F. Ribéry           34               France       86       85         52
# Pepe                34             Portugal       86       65         94
# P. Čech             35       Czech Republic       86       40         17
# D. Subašić          32              Croatia       85       51         31
# C. Marchisio        31                Italy       85       78         78
# Filipe Luís         31               Brazil       85       75         81
# V. Kompany          31              Belgium       85       61         87
# A. Barzagli         36                Italy       85       64         70
# Bruno               33                Spain       84       42         79
# E. Džeko            31   Bosnia Herzegovina       84       67         51
# Falcao              31             Colombia       84       73         75
# L. Koscielny        31               France       84       74         88
# G. Cahill           31              England       84       62         84
# Dani Alves          34               Brazil       84       79         78
# Aduriz              36                Spain       84       69         82
# M. Mandžukić        31              Croatia       83       68         88
# ...                ...                  ...      ...          ...        ...
# H. Nakabayashi      31                Japan       56       20         26
# W. Brown            40              England       56       36         36
# D. Pipe             33                Wales       56       61         96
# Y. Uekusa           34                Japan       56       63         45
# D. Coyne            43                Wales       55       36         36
# K. Ishihara         38                Japan       55       36         48
# D. Mulcahy          39  Republic of Ireland       55       27         68
# S. Kanazawa         33                Japan       55       47         61
# S. Naruoka          33                Japan       55       43         27
# J. Walker           43              England       55       22         41
# N. Ishikawa         36                Japan       55       35         58
# K. Tanno            31                Japan       55       26         19
# T. Torske           33               Norway       55       61         53
# K. Singh            31                India       54       47         20
# B. Molloy           33  Republic of Ireland       54       32         64
# J. McCombe          34              England       54       20         60
# J. Robben           34              Germany       54       48         62
# J. Bittner          35              England       54       34         34
# R. Iuliano          33                Italy       53       30         33
# N. Hatta            31                Japan       53       31         22
# I. Homma            36                Japan       52       55         50
# R. Kawai            38                Japan       52       39         54
# K. Ishii            31                Japan       52       69         29
# Y. Nishibe          36                Japan       52       25         17
# A. Al Basisi        39         Saudi Arabia       52       46         22
# P. Jennings         37              England       52       38         40
# K. Tokushige        33                Japan       51       25         18
# H. Tanaka           34                Japan       49       41         92
# Y. Uchimura         32                Japan       48       40         31
# B. Richardson       47              England       46       25         44
#
#                   Agility Balance Ball control Composure Crossing  \
# Name
# Cristiano Ronaldo  89      63           93        95       85
# M. Neuer           52      35           48        70       15
# Sergio Ramos       79      60           84        80       66
# L. Modrić          93      94           92        84       78
# G. Chiellini       59      64           57        82       58
# G. Buffon          55      49           28        70       13
# D. Godín           63      58           76        82       55
# Thiago Silva       74      68           80        83       60
# Z. Ibrahimović     81      41           88        91       76
# A. Robben          89      91           89        86       80
# David Silva        92      89           90        92       83
# S. Handanovič      42      36           24        62       12
# Iniesta            79      84           94        89       77
# Miranda            61      57           72        84       48
# F. Ribéry          88      91           90        86       81
# Pepe               63      49           62        77       46
# P. Čech            49      34           22        70       19
# D. Subašić         42      37           19        65       11
# C. Marchisio       81      79           85        84       76
# Filipe Luís        74      60           81        88       84
# V. Kompany         60      42           68        81       61
# A. Barzagli        51      64           65        82       40
# Bruno              53      59           83        86       60
# E. Džeko           57      36           80        79       63
# Falcao             85      75           82        87       55
# L. Koscielny       68      62           67        75       52
# G. Cahill          62      51           63        75       28
# Dani Alves         85      87           86        82       86
# Aduriz             53      57           80        87       54
# M. Mandžukić       67      53           77        80       72
# ...                   ...     ...          ...       ...      ...
# H. Nakabayashi     23      46           19        33       11
# W. Brown           31      35           19        29       11
# D. Pipe            53      72           57        52       60
# Y. Uekusa          61      56           35        34       35
# D. Coyne           48      58           31        57       13
# K. Ishihara        65      75           59        47       54
# D. Mulcahy         38      52           52        59       52
# S. Kanazawa        66      73           63        52       53
# S. Naruoka         82      72           56        57       55
# J. Walker          53      64           38        35       16
# N. Ishikawa        70      68           57        57       62
# K. Tanno           29      49           18        25       14
# T. Torske          54      68           51        66       49
# K. Singh           64      62           18        27       14
# B. Molloy          42      49           50        58       41
# J. McCombe         23      22           31        54       24
# J. Robben          56      59           61        55       54
# J. Bittner         36      42           25        41       10
# R. Iuliano         31      45           20        35       17
# N. Hatta           25      45           12        24       12
# I. Homma           56      79           41        38       39
# R. Kawai           35      55           47        65       39
# K. Ishii           54      74           49        44       49
# Y. Nishibe         25      32           13        67       14
# A. Al Basisi       38      49           20        24       16
# P. Jennings        54      50           22        46       18
# K. Tokushige       38      39           12        41       12
# H. Tanaka          58      78           42        47       44
# Y. Uchimura        33      65           57        62       51
# B. Richardson      35      44           22        44       11
#
#                           ...         Short passing Shot power Sliding tackle  \
# Name                      ...
# Cristiano Ronaldo         ...                83         94             23
# M. Neuer                  ...                55         25             11
# Sergio Ramos              ...                78         79             91
# L. Modrić                 ...                92         73             73
# G. Chiellini              ...                59         78             90
# G. Buffon                 ...                37         39             11
# D. Godín                  ...                79         67             89
# Thiago Silva              ...                79         74             88
# Z. Ibrahimović            ...                84         91             27
# A. Robben                 ...                84         87             26
# David Silva               ...                91         71             29
# S. Handanovič             ...                36         22             13
# Iniesta                   ...                92         65             56
# Miranda                   ...                70         70             86
# F. Ribéry                 ...                86         76             26
# Pepe                      ...                70         63             87
# P. Čech                   ...                35         21             12
# D. Subašić                ...                24         24             13
# C. Marchisio              ...                87         82             80
# Filipe Luís               ...                78         71             86
# V. Kompany                ...                72         75             84
# A. Barzagli               ...                65         54             88
# Bruno                     ...                87         84             85
# E. Džeko                  ...                77         86             16
# Falcao                    ...                78         79             19
# L. Koscielny              ...                76         54             84
# G. Cahill                 ...                65         63             84
# Dani Alves                ...                83         86             83
# Aduriz                    ...                71         83             49
# M. Mandžukić              ...                75         78             64
# ...                       ...                   ...        ...            ...
# H. Nakabayashi            ...                21         19             35
# W. Brown                  ...                16         16             16
# D. Pipe                   ...                56         36             58
# Y. Uekusa                 ...                46         40             17
# D. Coyne                  ...                28         21             19
# K. Ishihara               ...                57         53             50
# D. Mulcahy                ...                49         56             51
# S. Kanazawa               ...                63         67             55
# S. Naruoka                ...                58         55             22
# J. Walker                 ...                22         22             13
# N. Ishikawa               ...                59         53             38
# K. Tanno                  ...                23         23             13
# T. Torske                 ...                52         44             49
# K. Singh                  ...                23         15             14
# B. Molloy                 ...                55         42             55
# J. McCombe                ...                39         21             54
# J. Robben                 ...                65         54             32
# J. Bittner                ...                23         15             13
# R. Iuliano                ...                32         28             20
# N. Hatta                  ...                23         12             13
# I. Homma                  ...                52         48             52
# R. Kawai                  ...                62         37             55
# K. Ishii                  ...                44         67             24
# Y. Nishibe                ...                29         19             12
# A. Al Basisi              ...                21         19             20
# P. Jennings               ...                35         24             12
# K. Tokushige              ...                31         20             12
# H. Tanaka                 ...                57         48             49
# Y. Uchimura               ...                60         40             42
# B. Richardson             ...                12         13             13
#
#                   Sprint speed Stamina Standing tackle Strength  Vision  \
# Name
# Cristiano Ronaldo       91      92              31       80      85
# M. Neuer                61      44              10       83      70
# Sergio Ramos            77      84              89       81      63
# L. Modrić               71      82              80       58      90
# G. Chiellini            78      68              92       91      50
# G. Buffon               43      39              11       69      50
# D. Godín                67      67              86       80      52
# Thiago Silva            74      74              89       81      74
# Z. Ibrahimović          67      71              41       88      83
# A. Robben               86      68              26       67      83
# David Silva             65      78              44       56      92
# S. Handanovič           57      41              10       71      41
# Iniesta                 71      58              57       58      94
# Miranda                 74      65              90       80      58
# F. Ribéry               79      64              25       60      86
# Pepe                    70      62              86       84      48
# P. Čech                 44      32              13       65      53
# D. Subašić              54      32              14       80      52
# C. Marchisio            78      81              78       70      84
# Filipe Luís             82      91              83       74      70
# V. Kompany              64      74              85       88      59
# A. Barzagli             76      46              90       87      62
# Bruno                   41      76              84       77      83
# E. Džeko                61      70              28       82      70
# Falcao                  66      68              42       75      68
# L. Koscielny            76      75              87       76      56
# G. Cahill               63      69              85       80      56
# Dani Alves              84      76              79       55      78
# Aduriz                  70      64              44       83      73
# M. Mandžukić            76      87              64       87      74
# ...                        ...     ...             ...      ...     ...
# H. Nakabayashi          26      27              20       43      46
# W. Brown                22      24              14       62      15
# D. Pipe                 59      67              51       85      53
# Y. Uekusa               60      44              23       54      48
# D. Coyne                33      37              16       76      33
# K. Ishihara             38      36              51       56      55
# D. Mulcahy              30      34              53       67      55
# S. Kanazawa             42      33              56       46      48
# S. Naruoka              43      71              22       62      58
# J. Walker               35      19              11       62      32
# N. Ishikawa             45      53              41       60      56
# K. Tanno                23      22              11       45      45
# T. Torske               56      65              53       51      52
# K. Singh                42      33              15       53      15
# B. Molloy               31      33              56       65      50
# J. McCombe              21      42              52       75      19
# J. Robben               61      43              44       66      53
# J. Bittner              44      29              15       60      11
# R. Iuliano              34      24              18       53      33
# N. Hatta                26      14              12       42      34
# I. Homma                61      46              57       41      38
# R. Kawai                45      30              59       39      40
# K. Ishii                68      49              24       36      40
# Y. Nishibe              24      18              12       49      40
# A. Al Basisi            49      37              13       79      16
# P. Jennings             38      37              13       43      21
# K. Tokushige            20      23              13       62      33
# H. Tanaka               55      76              41       56      42
# Y. Uchimura             39      29              42       37      47
# B. Richardson           25      32              12       47      17
#
#                   Volleys Preferred Positions
# Name
# Cristiano Ronaldo  88                  ST LW
# M. Neuer           11                     GK
# Sergio Ramos       66                     CB
# L. Modrić          74                 CDM CM
# G. Chiellini       45                     CB
# G. Buffon          17                     GK
# D. Godín           47                     CB
# Thiago Silva       63                     CB
# Z. Ibrahimović     90                     ST
# A. Robben          86                  RW RM
# David Silva        79              LM CM CAM
# S. Handanovič      12                     GK
# Iniesta            74                  LM CM
# Miranda            51                     CB
# F. Ribéry          80                  LW LM
# Pepe               23                     CB
# P. Čech            17                     GK
# D. Subašić         13                     GK
# C. Marchisio       76                 CDM CM
# Filipe Luís        56                     LB
# V. Kompany         46                     CB
# A. Barzagli        35                     CB
# Bruno              48                 CDM CM
# E. Džeko           77                     ST
# Falcao             84                     ST
# L. Koscielny       35                     CB
# G. Cahill          47                     CB
# Dani Alves         68                     RB
# Aduriz             84                     ST
# M. Mandžukić       86                  LM ST
# ...                   ...                 ...
# H. Nakabayashi      5                     GK
# W. Brown           15                     GK
# D. Pipe            13                 RB RWB
# Y. Uekusa          13                     GK
# D. Coyne           11                     GK
# K. Ishihara        47                    CAM
# D. Mulcahy         44                 CDM CB
# S. Kanazawa        35                 CM CDM
# S. Naruoka         47                  RM LM
# J. Walker          11                     GK
# N. Ishikawa        48                     RW
# K. Tanno            8                     GK
# T. Torske          46                  LM LB
# K. Singh           17                     GK
# B. Molloy          32                 CM CDM
# J. McCombe         21                     CB
# J. Robben          60                 RM CDM
# J. Bittner         14                     GK
# R. Iuliano         14                     GK
# N. Hatta           10                     GK
# I. Homma           25                    CDM
# R. Kawai           27                 CB CDM
# K. Ishii           53               RW LM RM
# Y. Nishibe          6                     GK
# A. Al Basisi       11                     GK
# P. Jennings        14                     GK
# K. Tokushige        5                     GK
# H. Tanaka          35                 CDM CM
# Y. Uchimura        38                    CAM
# B. Richardson      12                     GK
#
# [2534 rows x 38 columns]

# %% [markdown]
# We can also pass multiple conditions in the square brackets by using the | and & operators. Note that each condition should be closed inside round brackets as well.

# %%
# Filter on players older than 30 and overall rating greater than 90
df[(df['Age'] > 30) & (df['Overall'] > 90)]
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing         ...          \
# Name                                                              ...
# Cristiano Ronaldo  63           93        95       85             ...
# M. Neuer           35           48        70       15             ...
#
#                   Short passing Shot power Sliding tackle Sprint speed  \
# Name
# Cristiano Ronaldo        83         94             23           91
# M. Neuer                 55         25             11           61
#
#                   Stamina Standing tackle Strength  Vision Volleys  \
# Name
# Cristiano Ronaldo  92              31       80      85      88
# M. Neuer           44              10       83      70      11
#
#                   Preferred Positions
# Name
# Cristiano Ronaldo              ST LW
# M. Neuer                          GK
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Create and Drop Columns

# %% [markdown]
# Another useful thing is to create new columns from existing ones as well as to drop columns that are not needed.

# %% [markdown]
# ### Create Columns

# %% [markdown]
# We can create new columns from existing ones by simply defining the new name as a string inside square brackets after calling the dataframe followed by the function of the other column(s). Let's look at an example:

# %%
# Create column of rating per year of age
df['Rating Per Year of Age'] = df['Overall'] / df['Age']

# Look at first 5 entries
df['Rating Per Year of Age'].head()
# Out:
# Name
# Cristiano Ronaldo    2.937500
# L. Messi             3.100000
# Neymar               3.680000
# L. Suárez            3.066667
# M. Neuer             2.967742
# Name: Rating Per Year of Age, dtype: float64

# %% [markdown]
# ### Drop Columns

# %% [markdown]
# Columns can be dropped by using the `drop()` function. The arguments are the column name (string) and the axis which should be equal to 1.

# %%
# Drop column just created
df = df.drop('Rating Per Year of Age', axis=1)

df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing         ...          \
# Name                                                              ...
# Cristiano Ronaldo  63           93        95       85             ...
# L. Messi           95           95        96       77             ...
# Neymar             82           95        92       75             ...
# L. Suárez          60           91        83       77             ...
# M. Neuer           35           48        70       15             ...
#
#                   Short passing Shot power Sliding tackle Sprint speed  \
# Name
# Cristiano Ronaldo        83         94             23           91
# L. Messi                 88         85             26           87
# Neymar                   81         80             33           90
# L. Suárez                83         87             38           77
# M. Neuer                 55         25             11           61
#
#                   Stamina Standing tackle Strength  Vision Volleys  \
# Name
# Cristiano Ronaldo  92              31       80      85      88
# L. Messi           73              28       59      90      85
# Neymar             78              24       53      80      83
# L. Suárez          89              45       80      84      88
# M. Neuer           44              10       83      70      11
#
#                   Preferred Positions
# Name
# Cristiano Ronaldo              ST LW
# L. Messi                          RW
# Neymar                            LW
# L. Suárez                         ST
# M. Neuer                          GK
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Group Data

# %% [markdown]
# We can also group the data according to some column(s). This will help if we are interested in certain groups within the dataset. We use the `groupby()` function to do this.
#
# Note that after the `groupby()` function we need to call an aggregation function for the grouped data. Examples are `mean()`, `sum()`, `min()` and `max()`. It will then return a column of the chosen aggregation for each numeric column. We can also then select the columns we want to see. Let's look at an example:

# %%
# Look at the average rating by age (first 5 rows)
df.groupby('Age').mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %% [markdown]
# It is possible to group by more than one column. We simply need to pass the list of columns.

# %%
# Look at the average rating by age and nationality (first 5 rows)
df.groupby(['Age', 'Nationality']).mean().head()
# Out:
#                  Overall
# Age Nationality
# 16  Argentina       56.0
#     England         61.5
#     France          54.0
#     Germany         57.0
#     Italy           61.0

# %% [markdown]
# ## Transforming Data

# %% [markdown]
# It is often the case that we want to format a column or columns inside our dataframe. We can transform a column using the `apply()` function, while we use the `applymap()` function to transform all the columns at once. The argument for these functions is a function that must be applied to the specific column or columns.
#
# We can create a function by using `def` or `lambda expressions`.

# %% [markdown]
# ### Def Expression

# %% [markdown]
# Let's format a column in our dataset. We start by creating the function.

# %%
# Using def
def year_to_month(x):
    "Converts no of years to no of months"
    return x * 12

# %%
# Change the age column to months and look at first 5 entries
df['Age'].apply(year_to_month).head()
# Out:
# Name
# Cristiano Ronaldo    384
# L. Messi             360
# Neymar               300
# L. Suárez            360
# M. Neuer             372
# Name: Age, dtype: int64

# %% [markdown]
# ### Lambda Expressions

# %% [markdown]
# You briefly covered lambda expressions in the Python Fundamentals. But let's have a quick recap:
#
# Lambda operator or lambda function is used for creating small, one-time and anonymous function objects in Python. Basic syntax:
#
# * `lambda` *arguments*: *expression*
#
# Lambda operator can have any number of arguments, but it can have only one expression. It cannot contain any statements and it returns a function object which can be assigned to any variable.
#
# Let's look at an example:

# %%
# Using lambda operator
year_to_month_lamb = lambda x: x * 12

# Print function answer
print('def: ', year_to_month(30))
print('lambda: ', year_to_month_lamb(30))
# Out:
# def:  360
# lambda:  360

# %% [markdown]
# So essentially it does the same as `def`, but it can only have one expression and there is no need to return anything.
#
# Let's use it to format a column in our dataset:

# %%
# Change the age column to months and look at first 5 entries
df['Age'].apply(lambda x: x*12).head()
# Out:
# Name
# Cristiano Ronaldo    384
# L. Messi             360
# Neymar               300
# L. Suárez            360
# M. Neuer             372
# Name: Age, dtype: int64

# %% [markdown]
# ### More Examples

# %% [markdown]
# For practice, let's create another function to create a column with the player position type, where types can be Forward, Midfielder, Back or GoalKeeper.

# %%
# Create function
def position_type(s):
    
    """"This function converts the individual positions (abbreviations) and classfies it
    as either a forward, midfielder, back or goal keeper"""
    
    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# %%
# Create position type column
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# Look at first 5 entries
df['Preferred Positions Type'].head()
# Out:
# Name
# Cristiano Ronaldo       Forward
# L. Messi                Forward
# Neymar                  Forward
# L. Suárez               Forward
# M. Neuer             GoalKeeper
# Name: Preferred Positions Type, dtype: object

# %% [markdown]
# Let's create another function to transform many columns at once using the `applymap()` function.
#
# A lot of the columns look like they should be numbers, but are actually stored as strings. We can check this by using the `info()` function:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 39 columns):
# Age                         17981 non-null int64
# Nationality                 17981 non-null object
# Overall                     17981 non-null int64
# Acceleration                17981 non-null object
# Aggression                  17981 non-null object
# Agility                     17981 non-null object
# Balance                     17981 non-null object
# Ball control                17981 non-null object
# Composure                   17981 non-null object
# Crossing                    17981 non-null object
# Curve                       17981 non-null object
# Dribbling                   17981 non-null object
# Finishing                   17981 non-null object
# Free kick accuracy          17981 non-null object
# GK diving                   17981 non-null object
# GK handling                 17981 non-null object
# GK kicking                  17981 non-null object
# GK positioning              17981 non-null object
# GK reflexes                 17981 non-null object
# Heading accuracy            17981 non-null object
# Interceptions               17981 non-null object
# Jumping                     17981 non-null object
# Long passing                17981 non-null object
# Long shots                  17981 non-null object
# Marking                     17981 non-null object
# Penalties                   17981 non-null object
# Positioning                 17981 non-null object
# Reactions                   17981 non-null object
# Short passing               17981 non-null object
# Shot power                  17981 non-null object
# Sliding tackle              17981 non-null object
# Sprint speed                17981 non-null object
# Stamina                     17981 non-null object
# Standing tackle             17981 non-null object
# Strength                    17981 non-null object
# Vision                      17981 non-null object
# Volleys                     17981 non-null object
# Preferred Positions         17981 non-null object
# Preferred Positions Type    17981 non-null object
# dtypes: int64(2), object(37)
# memory usage: 5.5+ MB

# %% [markdown]
# As you can see, most of the number columns (attributes) are stored as strings.
#
# We will create a function that transforms all the supposed number columns, to floats. For the strings, we will only select the first two characters to transform so that it returns a two digit number before the comma.

# %%
# Select all attribute columns
cols = ['Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

# %%
# Create function
def to_float(x):    
    "Transforms attribute columns to type float"
    
    if type(x) is int:
        return float(x)
    else:
        return float(x[0:2])

# %%
# Use applymap() function to transform all selected columns
df[cols] = df[cols].applymap(to_float)

# %% [markdown]
# Now let's look at the data types of the columns:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 39 columns):
# Age                         17981 non-null int64
# Nationality                 17981 non-null object
# Overall                     17981 non-null float64
# Acceleration                17981 non-null float64
# Aggression                  17981 non-null float64
# Agility                     17981 non-null float64
# Balance                     17981 non-null float64
# Ball control                17981 non-null float64
# Composure                   17981 non-null float64
# Crossing                    17981 non-null float64
# Curve                       17981 non-null float64
# Dribbling                   17981 non-null float64
# Finishing                   17981 non-null float64
# Free kick accuracy          17981 non-null float64
# GK diving                   17981 non-null float64
# GK handling                 17981 non-null float64
# GK kicking                  17981 non-null float64
# GK positioning              17981 non-null float64
# GK reflexes                 17981 non-null float64
# Heading accuracy            17981 non-null float64
# Interceptions               17981 non-null float64
# Jumping                     17981 non-null float64
# Long passing                17981 non-null float64
# Long shots                  17981 non-null float64
# Marking                     17981 non-null float64
# Penalties                   17981 non-null float64
# Positioning                 17981 non-null float64
# Reactions                   17981 non-null float64
# Short passing               17981 non-null float64
# Shot power                  17981 non-null float64
# Sliding tackle              17981 non-null float64
# Sprint speed                17981 non-null float64
# Stamina                     17981 non-null float64
# Standing tackle             17981 non-null float64
# Strength                    17981 non-null float64
# Vision                      17981 non-null float64
# Volleys                     17981 non-null float64
# Preferred Positions         17981 non-null object
# Preferred Positions Type    17981 non-null object
# dtypes: float64(35), int64(1), object(3)
# memory usage: 5.5+ MB

# %% [markdown]
# **NB Note:**
#
# **Use the two functions in this section (More Examples) for your project deliverable to distinguish between defenders (backs) and attackers (forwards), and also to transform your attribute columns to floats (i.e. perform these two transformations on the data before attempting to create the functions required for the project deliverable).**

# %% [markdown]
# ## Exercises
# #### Using the above dataframe, who is the oldest player with an Overall of at least 70?

# %%
df[(df['Age'] > 40) & (df['Overall'] > 70)].index[0]
# Out:
# 'O. Pérez'

# %% [markdown]
# #### What is the age of the youngest Norweigian player?

# %%
df[(df['Nationality'] == 'Norway')]['Age'].min()
# Out:
# 16

# %% [markdown]
# #### What is the average Overall for Brazillian players that are at least 26 years old?

# %%
df[(df['Nationality'] == 'Brazil') & (df['Age'] > 26)]['Overall'].mean()
# Out:
# 71.61961722488039

# %%
pd.set_option('display.max_rows',10)

# %%
df.groupby(['Nationality'])['Overall'].mean()  == 73.0
# Out:
# Nationality
# Afghanistan          False
# Albania              False
# Algeria              False
# Angola               False
# Antigua & Barbuda    False
#                      ...
# Venezuela            False
# Vietnam              False
# Wales                False
# Zambia               False
# Zimbabwe             False
# Name: Overall, Length: 165, dtype: bool

# %%
df[(df['Nationality'] == 'Algeria')]['Overall'].index[0]
# Out:
# 'R. Mahrez'

# %%
df[(df['Preferred Positions Type'] == 'Back')]['Sliding tackle'].index[0]
# Out:
# 'Sergio Ramos'

# %%
pd.set_option('display.max_rows',1000)

# %%
df.groupby(['Nationality', 'Preferred Positions Type'])['Overall'].mean()
# Out:
# Nationality           Preferred Positions Type
# Afghanistan           Midfielder                  56.333333
# Albania               Back                        68.000000
#                       Forward                     63.666667
#                       GoalKeeper                  76.000000
#                       Midfielder                  65.764706
# Algeria               Back                        71.857143
#                       Forward                     70.300000
#                       GoalKeeper                  66.666667
#                       Midfielder                  71.166667
# Angola                Back                        70.400000
#                       Forward                     68.000000
#                       GoalKeeper                  63.000000
#                       Midfielder                  68.400000
# Antigua & Barbuda     Back                        65.000000
#                       Forward                     56.500000
#                       Midfielder                  57.500000
# Argentina             Back                        68.045775
#                       Forward                     67.953125
#                       GoalKeeper                  66.229358
#                       Midfielder                  67.902632
# Armenia               Back                        62.000000
#                       Forward                     65.500000
#                       Midfielder                  69.000000
# Australia             Back                        63.352941
#                       Forward                     60.081081
#                       GoalKeeper                  62.533333
#                       Midfielder                  63.493333
# Austria               Back                        65.152941
#                       Forward                     63.428571
#                       GoalKeeper                  62.714286
#                       Midfielder                  64.923077
# Azerbaijan            Back                        63.000000
#                       Forward                     64.000000
#                       Midfielder                  65.500000
# Barbados              Forward                     65.000000
# Belarus               Back                        72.250000
#                       GoalKeeper                  71.000000
#                       Midfielder                  69.250000
# Belgium               Back                        67.487500
#                       Forward                     69.666667
#                       GoalKeeper                  67.568182
#                       Midfielder                  68.269565
# Belize                Midfielder                  64.000000
# Benin                 Back                        68.250000
#                       Forward                     68.200000
#                       GoalKeeper                  67.500000
#                       Midfielder                  67.666667
# Bermuda               Forward                     66.000000
#                       GoalKeeper                  58.000000
#                       Midfielder                  63.000000
# Bolivia               Back                        65.200000
#                       Forward                     65.000000
#                       GoalKeeper                  65.250000
#                       Midfielder                  65.916667
# Bosnia Herzegovina    Back                        69.000000
#                       Forward                     70.500000
#                       GoalKeeper                  69.000000
#                       Midfielder                  69.115385
# Brazil                Back                        71.490975
#                       Forward                     70.028902
#                       GoalKeeper                  71.611940
#                       Midfielder                  70.681356
# Brunei Darussalam     Midfielder                  55.000000
# Bulgaria              Back                        65.363636
#                       Forward                     69.166667
#                       GoalKeeper                  63.400000
#                       Midfielder                  69.454545
# Burkina Faso          Back                        66.250000
#                       Forward                     66.750000
#                       GoalKeeper                  66.000000
#                       Midfielder                  72.200000
# Burundi               Forward                     64.000000
# Cameroon              Back                        67.935484
#                       Forward                     67.809524
#                       GoalKeeper                  70.571429
#                       Midfielder                  66.444444
# Canada                Back                        64.428571
#                       Forward                     64.909091
#                       GoalKeeper                  63.600000
#                       Midfielder                  63.560000
# Cape Verde            Back                        71.166667
#                       Forward                     73.000000
#                       GoalKeeper                  63.000000
#                       Midfielder                  67.916667
# Central African Rep.  Back                        70.000000
#                       Forward                     61.000000
#                       Midfielder                  68.500000
# Chad                  Forward                     74.000000
#                       Midfielder                  62.000000
# Chile                 Back                        71.007874
#                       Forward                     70.423729
#                       GoalKeeper                  70.777778
#                       Midfielder                  71.013072
# China PR              Back                        65.166667
#                       Forward                     67.500000
#                       GoalKeeper                  71.666667
#                       Midfielder                  69.555556
# Colombia              Back                        65.527174
#                       Forward                     66.823009
#                       GoalKeeper                  61.226415
#                       Midfielder                  66.231405
# Comoros               Back                        69.000000
#                       Forward                     71.000000
#                       GoalKeeper                  70.000000
#                       Midfielder                  67.200000
# Congo                 Back                        68.333333
#                       Forward                     62.625000
#                       GoalKeeper                  65.000000
#                       Midfielder                  65.142857
# Costa Rica            Back                        71.272727
#                       Forward                     64.500000
#                       GoalKeeper                  71.666667
#                       Midfielder                  69.363636
# Croatia               Back                        67.447368
#                       Forward                     70.250000
#                       GoalKeeper                  67.272727
#                       Midfielder                  70.525000
# Cuba                  Midfielder                  73.000000
# Curacao               Back                        66.666667
#                       Forward                     65.000000
#                       GoalKeeper                  74.000000
#                       Midfielder                  68.200000
# Cyprus                Back                        62.833333
#                       Forward                     59.500000
#                       Midfielder                  63.666667
# Czech Republic        Back                        70.173913
#                       Forward                     69.538462
#                       GoalKeeper                  69.461538
#                       Midfielder                  70.916667
# DR Congo              Back                        67.000000
#                       Forward                     69.785714
#                       GoalKeeper                  65.333333
#                       Midfielder                  67.541667
# Denmark               Back                        63.503817
#                       Forward                     63.264151
#                       GoalKeeper                  62.166667
#                       Midfielder                  63.516667
# Dominican Republic    Back                        66.500000
#                       Forward                     76.000000
# Ecuador               Back                        70.000000
#                       Forward                     72.875000
#                       GoalKeeper                  70.500000
#                       Midfielder                  69.571429
# Egypt                 Back                        69.000000
#                       Forward                     73.250000
#                       GoalKeeper                  70.666667
#                       Midfielder                  69.642857
# El Salvador           Midfielder                  69.000000
# England               Back                        63.669104
#                       Forward                     62.513245
#                       GoalKeeper                  61.078652
#                       Midfielder                  63.393035
# Equatorial Guinea     Back                        69.500000
#                       Forward                     70.000000
#                       GoalKeeper                  67.000000
#                       Midfielder                  64.000000
# Eritrea               Forward                     71.000000
# Estonia               Back                        65.600000
#                       Midfielder                  63.333333
# Ethiopia              Midfielder                  65.500000
# FYR Macedonia         Back                        66.250000
#                       Forward                     68.833333
#                       GoalKeeper                  67.333333
#                       Midfielder                  63.750000
# Faroe Islands         Back                        62.000000
#                       Forward                     63.500000
#                       Midfielder                  58.666667
# Fiji                  Forward                     69.000000
# Finland               Back                        64.304348
#                       Forward                     65.000000
#                       GoalKeeper                  61.666667
#                       Midfielder                  65.150000
# France                Back                        67.483974
#                       Forward                     67.161458
#                       GoalKeeper                  65.771930
#                       Midfielder                  67.661111
# Gabon                 Back                        69.333333
#                       Forward                     72.666667
#                       GoalKeeper                  66.000000
#                       Midfielder                  70.800000
# Gambia                Back                        68.000000
#                       Forward                     64.750000
#                       Midfielder                  65.000000
# Georgia               Back                        68.500000
#                       Forward                     65.166667
#                       GoalKeeper                  69.666667
#                       Midfielder                  66.285714
# Germany               Back                        66.355091
#                       Forward                     65.748344
#                       GoalKeeper                  65.570513
#                       Midfielder                  65.680000
# Ghana                 Back                        66.137931
#                       Forward                     67.307692
#                       GoalKeeper                  59.500000
#                       Midfielder                  67.327586
# Gibraltar             Back                        64.000000
#                       Midfielder                  64.000000
# Greece                Back                        69.558824
#                       Forward                     69.666667
#                       GoalKeeper                  67.466667
#                       Midfielder                  68.405405
# Grenada               Back                        64.000000
# Guam                  Back                        69.000000
# Guatemala             GoalKeeper                  72.000000
# Guinea                Back                        65.750000
#                       Forward                     68.400000
#                       Midfielder                  70.181818
# Guinea Bissau         Back                        65.000000
#                       Forward                     65.500000
#                       Midfielder                  66.666667
# Guyana                Back                        60.000000
#                       Midfielder                  64.000000
# Haiti                 Back                        67.500000
#                       Forward                     60.500000
#                       GoalKeeper                  66.000000
#                       Midfielder                  61.600000
# Honduras              Back                        70.200000
#                       Forward                     71.500000
#                       Midfielder                  67.750000
# Hong Kong             Midfielder                  54.000000
# Hungary               Back                        68.600000
#                       Forward                     66.900000
#                       GoalKeeper                  69.600000
#                       Midfielder                  69.166667
# Iceland               Back                        65.875000
#                       Forward                     66.692308
#                       GoalKeeper                  64.250000
#                       Midfielder                  66.250000
# India                 Back                        57.100000
#                       Forward                     59.100000
#                       GoalKeeper                  57.500000
#                       Midfielder                  57.500000
# Iran                  Back                        68.750000
#                       Forward                     70.714286
#                       GoalKeeper                  65.666667
#                       Midfielder                  65.333333
# Iraq                  Back                        66.000000
#                       Forward                     68.000000
#                       Midfielder                  69.500000
# Israel                Back                        69.000000
#                       Forward                     73.250000
#                       GoalKeeper                  65.000000
#                       Midfielder                  71.166667
# Italy                 Back                        67.660448
#                       Forward                     67.203297
#                       GoalKeeper                  64.747748
#                       Midfielder                  67.037815
# Ivory Coast           Back                        68.407407
#                       Forward                     67.200000
#                       GoalKeeper                  66.000000
#                       Midfielder                  69.375000
# Jamaica               Back                        67.142857
#                       Forward                     64.000000
#                       GoalKeeper                  71.000000
#                       Midfielder                  64.909091
# Japan                 Back                        62.264286
#                       Forward                     63.049180
#                       GoalKeeper                  60.541667
#                       Midfielder                  62.673469
# Kazakhstan            Back                        66.000000
#                       Midfielder                  66.000000
# Kenya                 Back                        60.500000
#                       Forward                     64.000000
#                       GoalKeeper                  67.000000
#                       Midfielder                  77.000000
# Korea DPR             Forward                     63.000000
#                       Midfielder                  60.000000
# Korea Republic        Back                        64.550459
#                       Forward                     64.150943
#                       GoalKeeper                  63.804348
#                       Midfielder                  64.836066
# Kosovo                Back                        66.000000
#                       Forward                     68.800000
#                       GoalKeeper                  64.000000
#                       Midfielder                  65.235294
# Kuwait                Back                        61.000000
#                       Midfielder                  71.000000
# Kyrgyzstan            Forward                     58.000000
# Latvia                Back                        63.500000
#                       Forward                     69.333333
#                       GoalKeeper                  68.500000
# Lebanon               Forward                     60.500000
#                       GoalKeeper                  61.000000
#                       Midfielder                  65.500000
# Liberia               Forward                     64.000000
# Libya                 Forward                     67.500000
# Liechtenstein         Back                        66.000000
#                       Forward                     56.000000
#                       Midfielder                  73.000000
# Lithuania             Back                        66.000000
#                       Forward                     68.000000
#                       GoalKeeper                  62.000000
#                       Midfielder                  63.250000
# Luxembourg            Back                        67.666667
#                       GoalKeeper                  67.000000
#                       Midfielder                  64.500000
# Madagascar            Forward                     72.000000
#                       Midfielder                  65.000000
# Mali                  Back                        67.416667
#                       Forward                     68.800000
#                       GoalKeeper                  70.000000
#                       Midfielder                  66.428571
# Malta                 Back                        62.500000
#                       Midfielder                  61.000000
# Mauritania            Back                        63.000000
#                       Midfielder                  70.000000
# Mauritius             Midfielder                  67.000000
# Mexico                Back                        65.825758
#                       Forward                     64.600000
#                       GoalKeeper                  63.509804
#                       Midfielder                  66.819672
# Moldova               Back                        69.000000
#                       Midfielder                  70.333333
# Montenegro            Back                        70.000000
#                       Forward                     71.166667
#                       GoalKeeper                  61.000000
#                       Midfielder                  67.500000
# Montserrat            Back                        67.000000
#                       Forward                     66.000000
#                       Midfielder                  62.500000
# Morocco               Back                        69.111111
#                       Forward                     68.315789
#                       GoalKeeper                  70.500000
#                       Midfielder                  70.512821
# Mozambique            Back                        75.500000
#                       Forward                     66.000000
# Namibia               Back                        63.000000
#                       Midfielder                  66.000000
# Netherlands           Back                        68.724359
#                       Forward                     68.026667
#                       GoalKeeper                  65.841270
#                       Midfielder                  68.348148
# New Caledonia         Midfielder                  68.500000
# New Zealand           Back                        62.923077
#                       Forward                     64.600000
#                       GoalKeeper                  59.833333
#                       Midfielder                  59.111111
# Niger                 Forward                     71.000000
#                       Midfielder                  64.000000
# Nigeria               Back                        66.040000
#                       Forward                     66.607843
#                       GoalKeeper                  69.200000
#                       Midfielder                  67.066667
# Northern Ireland      Back                        62.444444
#                       Forward                     61.947368
#                       GoalKeeper                  64.166667
#                       Midfielder                  62.500000
# Norway                Back                        63.899083
#                       Forward                     62.478873
#                       GoalKeeper                  61.466667
#                       Midfielder                  62.983740
# Oman                  GoalKeeper                  73.000000
# Palestine             Forward                     63.000000
#                       Midfielder                  64.000000
# Panama                Back                        65.142857
#                       Forward                     65.500000
#                       Midfielder                  66.600000
# Paraguay              Back                        68.952381
#                       Forward                     69.750000
#                       GoalKeeper                  67.400000
#                       Midfielder                  70.739130
# Peru                  Back                        68.818182
#                       Forward                     71.500000
#                       GoalKeeper                  69.500000
#                       Midfielder                  68.000000
# Philippines           Back                        58.500000
#                       GoalKeeper                  68.000000
# Poland                Back                        64.460000
#                       Forward                     63.882353
#                       GoalKeeper                  62.777778
#                       Midfielder                  64.340909
# Portugal              Back                        70.653846
#                       Forward                     69.862069
#                       GoalKeeper                  69.000000
#                       Midfielder                  71.333333
# Puerto Rico           Back                        66.000000
#                       GoalKeeper                  66.000000
# Qatar                 Back                        65.500000
#                       Forward                     63.000000
#                       Midfielder                  64.000000
# Republic of Ireland   Back                        59.923077
#                       Forward                     60.028169
#                       GoalKeeper                  58.446809
#                       Midfielder                  60.724359
# Romania               Back                        68.500000
#                       Forward                     68.333333
#                       GoalKeeper                  68.333333
#                       Midfielder                  69.227273
# Russia                Back                        67.744681
#                       Forward                     65.577778
#                       GoalKeeper                  65.586207
#                       Midfielder                  66.211009
# San Marino            GoalKeeper                  54.000000
# Saudi Arabia          Back                        61.596330
#                       Forward                     60.200000
#                       GoalKeeper                  59.489362
#                       Midfielder                  61.456522
# Scotland              Back                        62.270000
#                       Forward                     61.617021
#                       GoalKeeper                  61.800000
#                       Midfielder                  64.000000
# Senegal               Back                        68.523810
#                       Forward                     67.948718
#                       GoalKeeper                  66.200000
#                       Midfielder                  68.651163
# Serbia                Back                        70.583333
#                       Forward                     69.320000
#                       GoalKeeper                  67.076923
#                       Midfielder                  71.829787
# Sierra Leone          Back                        65.500000
#                       Forward                     66.833333
#                       Midfielder                  58.000000
# Slovakia              Back                        68.066667
#                       Forward                     65.800000
#                       GoalKeeper                  65.000000
#                       Midfielder                  66.937500
# Slovenia              Back                        67.681818
#                       Forward                     67.615385
#                       GoalKeeper                  76.333333
#                       Midfielder                  67.125000
# Somalia               Midfielder                  68.000000
# South Africa          Back                        68.136364
#                       Forward                     64.900000
#                       GoalKeeper                  67.888889
#                       Midfielder                  68.346154
# Spain                 Back                        69.805085
#                       Forward                     69.961290
#                       GoalKeeper                  68.504132
#                       Midfielder                  70.498715
# Sri Lanka             Midfielder                  60.000000
# St Kitts Nevis        Back                        66.000000
#                       Forward                     57.000000
#                       Midfielder                  70.000000
# St Lucia              Back                        62.000000
# Sudan                 Forward                     58.000000
#                       Midfielder                  62.000000
# Suriname              Back                        70.000000
#                       Midfielder                  68.000000
# Swaziland             Midfielder                  63.000000
# Sweden                Back                        64.606557
#                       Forward                     64.917808
#                       GoalKeeper                  63.725000
#                       Midfielder                  64.436090
# Switzerland           Back                        64.164557
#                       Forward                     62.689655
#                       GoalKeeper                  63.571429
#                       Midfielder                  64.000000
# Syria                 Forward                     77.000000
#                       Midfielder                  68.000000
# São Tomé & Príncipe   Forward                     64.000000
# Tanzania              Forward                     67.500000
# Thailand              Forward                     65.000000
#                       Midfielder                  53.000000
# Togo                  Back                        70.000000
#                       Forward                     65.000000
#                       Midfielder                  72.166667
# Trinidad & Tobago     Back                        66.000000
#                       Forward                     68.500000
#                       Midfielder                  71.000000
# Tunisia               Back                        70.125000
#                       Forward                     68.714286
#                       GoalKeeper                  63.000000
#                       Midfielder                  67.000000
# Turkey                Back                        67.715909
#                       Forward                     66.777778
#                       GoalKeeper                  65.511628
#                       Midfielder                  67.518797
# Turkmenistan          Midfielder                  63.000000
# Uganda                Back                        64.000000
#                       Forward                     64.000000
#                       Midfielder                  61.500000
# Ukraine               Back                        70.500000
#                       Forward                     69.666667
#                       GoalKeeper                  72.000000
#                       Midfielder                  69.166667
# United States         Back                        65.576642
#                       Forward                     64.690909
#                       GoalKeeper                  63.408451
#                       Midfielder                  65.415254
# Uruguay               Back                        69.581395
#                       Forward                     69.973684
#                       GoalKeeper                  70.733333
#                       Midfielder                  68.736842
# Uzbekistan            Back                        80.000000
#                       Forward                     63.000000
#                       Midfielder                  66.333333
# Venezuela             Back                        69.538462
#                       Forward                     70.428571
#                       GoalKeeper                  71.250000
#                       Midfielder                  67.300000
# Vietnam               Midfielder                  61.000000
# Wales                 Back                        64.078431
#                       Forward                     64.095238
#                       GoalKeeper                  63.583333
#                       Midfielder                  64.743590
# Zambia                Back                        71.000000
#                       Forward                     60.000000
#                       GoalKeeper                  63.000000
#                       Midfielder                  63.250000
# Zimbabwe              Back                        65.500000
#                       Forward                     67.000000
#                       Midfielder                  66.714286
# Name: Overall, dtype: float64

# %%
df[(df['Age'] == df['Age'].max())]['Nationality']
# Out:
# Name
# B. Richardson    England
# Name: Nationality, dtype: object

# %%
df.groupby(['Preferred Positions Type'])['Reactions','Acceleration'].mean()
# Out:
#                           Reactions  Acceleration
# Preferred Positions Type
# Back                      61.522230     64.384405
# Forward                   62.030741     71.011682
# GoalKeeper                59.470867     40.229749
# Midfielder                62.655931     69.126163

# %%
pd.set_option('display.max_columns',1000)

# %%
df.groupby(['Preferred Positions Type']).mean()
# Out:
#                                 Age    Overall  Acceleration  Aggression  \
# Preferred Positions Type
# Back                      25.436731  66.495383     64.384405   65.494699
# Forward                   24.630188  66.209038     71.011682   51.642176
# GoalKeeper                26.016580  64.811937     40.229749   27.578873
# Midfielder                24.867336  66.500813     69.126163   58.194563
#
#                             Agility    Balance  Ball control  Composure  \
# Preferred Positions Type
# Back                      60.121067  61.526334     57.074213  58.661594
# Forward                   68.462650  65.883800     64.982170  60.876729
# GoalKeeper                41.912364  44.454287     21.961630  37.512080
# Midfielder                70.186143  70.731275     66.696115  61.945191
#
#                            Crossing      Curve  Dribbling  Finishing  \
# Preferred Positions Type
# Back                      51.287278  43.687073  51.841997  34.787449
# Forward                   50.086689  53.173071  64.525361  65.780203
# GoalKeeper                16.028423  16.665088  16.203221  14.516817
# Midfielder                58.689171  57.126311  65.186586  53.928645
#
#                           Free kick accuracy  GK diving  GK handling  \
# Preferred Positions Type
# Back                               39.387141  10.597982    10.598324
# Forward                            46.353827  10.499846    10.628343
# GoalKeeper                         16.126480  62.988157    60.675983
# Midfielder                         53.280396  10.544837    10.618407
#
#                           GK kicking  GK positioning  GK reflexes  \
# Preferred Positions Type
# Back                       10.602941       10.601744    10.566860
# Forward                    10.676606       10.499231    10.537658
# GoalKeeper                 59.424443       60.843676    63.848887
# Midfielder                 10.672773       10.594918    10.625055
#
#                           Heading accuracy  Interceptions    Jumping  \
# Preferred Positions Type
# Back                             60.916211      63.728112  68.800616
# Forward                          60.642484      27.517369  66.074085
# GoalKeeper                       16.108479      18.032212  58.339176
# Midfielder                       52.087753      49.643817  62.829665
#
#                           Long passing  Long shots    Marking  Penalties  \
# Preferred Positions Type
# Back                         53.082421   39.892613  64.180404  43.962722
# Forward                      46.835229   59.583461  23.739010  62.285583
# GoalKeeper                   26.719090   15.131691  13.270962  22.028423
# Midfielder                   62.454277   57.502290  45.943566  55.285862
#
#                           Positioning  Reactions  Short passing  Shot power  \
# Preferred Positions Type
# Back                        43.440834  61.522230      58.344562   51.924077
# Forward                     64.881033  62.030741      58.867507   66.457117
# GoalKeeper                  13.803411  59.470867      28.401705   24.290857
# Midfielder                  58.760674  62.655931      67.055843   63.356774
#
#                           Sliding tackle  Sprint speed    Stamina  \
# Preferred Positions Type
# Back                           65.404412     65.448358  68.021888
# Forward                        24.522902     71.493083  64.523517
# GoalKeeper                     14.606821     40.526291  32.057793
# Midfielder                     48.032501     68.427390  68.020830
#
#                           Standing tackle   Strength     Vision    Volleys
# Preferred Positions Type
# Back                            66.863543  70.360123  45.786423  35.974863
# Forward                         26.908392  66.409468  56.045804  58.225330
# GoalKeeper                      14.806253  60.914732  37.171009  14.906206
# Midfielder                      50.474664  61.504210  62.587236  51.078889

# %%
df['Preferred Positions Type'].value_counts()
# Out:
# Midfielder    6769
# Back          5848
# Forward       3253
# GoalKeeper    2111
# Name: Preferred Positions Type, dtype: int64

# %%
df[(df['Nationality'] == 'Portugal') & (df['Age'] < 25)]['Overall'].index[0]
# Out:
# 'Bernardo Silva'

# %% [markdown]
# ## When to use Dataframes

# %% [markdown]
# DataFrames allow you to store and manipulate tabular data in rows of observations and columns of variables. It is therefore a two-dimensional labeled data structure. We should use a pandas dataframe if all of the following statements hold:
#
# * We have 2-dimensional data (rows and columns)
# * The data type is the same within a column
# * We are interested in the index (rows) and column names

# %% [markdown]
# That is the end of this tutorial. You should have a better understanding of how to manipulate pandas dataframes. You have now covered all of the tutorials in the Python Data Structures section of the course. Well done!!!
